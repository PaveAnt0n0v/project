# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#✔-Комментарий-ревьюера-V.2" data-toc-modified-id="✔-Комментарий-ревьюера-V.2-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>✔ Комментарий ревьюера V.2</a></span></li></ul></li><li><span><a href="#-Комментарий-ревьюера" data-toc-modified-id="-Комментарий-ревьюера-1"><span class="toc-item-num">1&nbsp;&nbsp;</span> Комментарий ревьюера</a></span><ul class="toc-item"><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#!!-Комментарий-ревьюера" data-toc-modified-id="!!-Комментарий-ревьюера-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>!! Комментарий ревьюера</a></span></li><li><span><a href="#👀-Комментарий-ревьюера" data-toc-modified-id="👀-Комментарий-ревьюера-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>👀 Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Комментарий студента</a></span></li><li><span><a href="#Комментарий-студента-" data-toc-modified-id="Комментарий-студента--1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Комментарий студента </a></span></li></ul></li><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Комментарий студента</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Комментарий студента</a></span></li><li><span><a href="#✔-Комментарий-ревьюера-V.2" data-toc-modified-id="✔-Комментарий-ревьюера-V.2-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>✔ Комментарий ревьюера V.2</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Комментарий студента</a></span></li><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Комментарий студента</a></span></li><li><span><a href="#✔-Комментарий-ревьюера-V.2" data-toc-modified-id="✔-Комментарий-ревьюера-V.2-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>✔ Комментарий ревьюера V.2</a></span></li><li><span><a href="#✔-Комментарий-ревьюера-V.2" data-toc-modified-id="✔-Комментарий-ревьюера-V.2-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>✔ Комментарий ревьюера V.2</a></span></li><li><span><a href="#!!-Комментарий-ревьюера" data-toc-modified-id="!!-Комментарий-ревьюера-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>!! Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Комментарий студента</a></span></li><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#👀-Комментарий-ревьюера" data-toc-modified-id="👀-Комментарий-ревьюера-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>👀 Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-3.11"><span class="toc-item-num">3.11&nbsp;&nbsp;</span>Комментарий студента</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.12"><span class="toc-item-num">3.12&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-3.13"><span class="toc-item-num">3.13&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-3.14"><span class="toc-item-num">3.14&nbsp;&nbsp;</span>Комментарий студента</a></span></li><li><span><a href="#✔-Комментарий-ревьюера-V.2" data-toc-modified-id="✔-Комментарий-ревьюера-V.2-3.15"><span class="toc-item-num">3.15&nbsp;&nbsp;</span>✔ Комментарий ревьюера V.2</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Комментарий студента</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#👀-Комментарий-ревьюера" data-toc-modified-id="👀-Комментарий-ревьюера-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>👀 Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Комментарий студента</a></span></li><li><span><a href="#✔-Комментарий-ревьюера-V.2" data-toc-modified-id="✔-Комментарий-ревьюера-V.2-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>✔ Комментарий ревьюера V.2</a></span></li><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-5.9"><span class="toc-item-num">5.9&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-5.10"><span class="toc-item-num">5.10&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-5.11"><span class="toc-item-num">5.11&nbsp;&nbsp;</span>Комментарий студента</a></span></li><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-5.12"><span class="toc-item-num">5.12&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#✔-Комментарий-ревьюера-V.2" data-toc-modified-id="✔-Комментарий-ревьюера-V.2-5.13"><span class="toc-item-num">5.13&nbsp;&nbsp;</span>✔ Комментарий ревьюера V.2</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод</a></span><ul class="toc-item"><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li></ul></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ## Изучение данных из файла

# %% [markdown]
# Составляем первые впечатления о данных.

# %%
import pandas as pd # импорт библиотеки pandas
import seaborn as sns # импорт библиотеки seaborn
import matplotlib.pyplot as plt # импорт библиотеки matplotlib.pyplot для работы с графиками
import numpy as np # импорт библиотеки numpy
from pymystem3 import Mystem # импорт библиотеки pymystem3
m = Mystem()

# %%
df = pd.read_csv('/datasets/real_estate_data.csv', sep='\t') # чтение файла с данными и сохранение в df

# %%
pd.set_option('display.max_columns', None) # выводим все столбцы

# %%
df.head(5) # получение первых 5 строк таблицы df
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0         51.0      8          NaN   False
# 1             NaN          11.0         18.6      1          NaN   False
# 2             NaN           5.0         34.3      4          NaN   False
# 3             NaN          14.0          NaN      9          NaN   False
# 4            3.03          14.0         32.0     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
df.info() # получение общей информации о данных в таблице df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %%
df.describe() # описание столбцов с числовыми данными.
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    14504.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.771499
# std        5.682529  1.088701e+07     35.654083      1.078405        1.261056
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21796.000000  23699.000000  21421.000000  12180.000000
# mean      10.673824     34.457852      5.892358     10.569807      1.150082
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Согласно документации к данным:
#
# * `airports_nearest` — расстояние до ближайшего аэропорта в метрах (м)
# *`balcony` — число балконов
# *`ceiling_height` — высота потолков (м)
# *`cityCenters_nearest` — расстояние до центра города (м)
# *`days_exposition` — сколько дней было размещено объявление (от публикации до снятия)
# *`first_day_exposition` — дата публикации
# *`floor` — этаж
# *`floors_total` — всего этажей в доме
# *`is_apartment` — апартаменты (булев тип)
# *`kitchen_area` — площадь кухни в квадратных метрах (м²)
# *`last_price` — цена на момент снятия с публикации
# *`living_area` — жилая площадь в квадратных метрах (м²)
# *`locality_name` — название населённого пункта
# *`open_plan` — свободная планировка (булев тип)
# *`parks_around3000` — число парков в радиусе 3 км
# *`parks_nearest` — расстояние до ближайшего парка (м)
# *`ponds_around3000` — число водоёмов в радиусе 3 км
# *`ponds_nearest` — расстояние до ближайшего водоёма (м)
# *`rooms` — число комнат
# *`studio` — квартира-студия (булев тип)
# *`total_area` — площадь квартиры в квадратных метрах (м²)
# *`total_images` — число фотографий квартиры в объявлении
#
#
# Таблица состоит из 23699 строк и 22 колонок. В некоторых столбцах имеются пропуски, которые могут повлиять на проверку выдвинутых гипотез.
#
# Также,например, в столбеце `living_area` стандартное отклонение больше медианного значения. Такие данные необходимо проанализировать и отфильтровать.

# %% [markdown]
# ## Предобработка данных

# %%
df.isna().sum() # подсчёт пропусков
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Пропуски обнаружены в больше,чем в половине столбцов. Некоторые из них в количестве очень малы(`floors_total`,`locality_name`). Но у столбцов таких как  `ceiling_height`, `balcony`,`cityCenters_nearest`. Эти пропуски необходимо заполнить.

# %%
df = df.dropna(subset = ['floors_total','locality_name'])# удаление пропусков в столбцах 'floors_total','locality_name'

# %% [markdown]
# В столбце `balcony` пропусков 11519. Есть предположение,что при формировании объявления не было указано в количестве балконов их отсуствие.

# %%
df['balcony'] = df['balcony'].fillna(0) # замена пропусков в столбце `balcony` на ноль

# %% [markdown]
# В столбце `is_apartment` заменили все пропуски на False. Так не было указано ,что квартира не является апартаментами.

# %%
df['is_apartment'] = df['is_apartment'].fillna(False) # замена пропусков в столбце 'is_apartment' на False

# %% [markdown]
# Заменили в столбцах `parks_nearest`, `ponds_nearest` пропуски на ноль. Если рядом с домом отсутвует парк или водоем, то расстояние до них не будет никакого.

# %%
df.loc[df['parks_around3000'] == 0,'parks_nearest'] = 0 # замена пропусков в столбце 'parks_nearest' на ноль

# %%
df.loc[df['ponds_around3000'] == 0,'ponds_nearest'] = 0 # замена пропусков в столбце 'ponds_nearest' на ноль

# %%
df['kitchen_area'] = df['kitchen_area'].fillna(df['total_area'] - df['living_area']) # заполняем пропуска в столбце 'kitchen_area' при изместных столбцах 'total_area' , 'living_area' 
df['kitchen_area'] = df['kitchen_area'].fillna(df.groupby('total_area')['kitchen_area'].transform('median')) # остальные пропуски заполняем медианой с группировкой по total_area

# %%
# Код ревьюера

data_copy = df.copy()

data_copy['ceiling_height'] = data_copy['ceiling_height'].astype('float')

data_copy.dropna(subset=['cityCenters_nearest'])\
    .groupby(pd.cut(data_copy['cityCenters_nearest'].dropna().astype('float'), bins=50)).agg(высота_полотков=('ceiling_height','median'))
# Out:
#                       высота_полотков
# cityCenters_nearest
# (115.213, 1496.74]              3.200
# (1496.74, 2812.48]              3.200
# (2812.48, 4128.22]              3.100
# (4128.22, 5443.96]              3.000
# (5443.96, 6759.7]               3.000
# (6759.7, 8075.44]               2.800
# (8075.44, 9391.18]              2.800
# (9391.18, 10706.92]             2.600
# (10706.92, 12022.66]            2.600
# (12022.66, 13338.4]             2.600
# (13338.4, 14654.14]             2.605
# (14654.14, 15969.88]            2.600
# (15969.88, 17285.62]            2.600
# (17285.62, 18601.36]            2.600
# (18601.36, 19917.1]             2.620
# (19917.1, 21232.84]             2.700
# (21232.84, 22548.58]            2.650
# (22548.58, 23864.32]            2.600
# (23864.32, 25180.06]            2.650
# (25180.06, 26495.8]             2.550
# (26495.8, 27811.54]             2.600
# (27811.54, 29127.28]            2.600
# (29127.28, 30443.02]            2.600
# ...

# %%
df['living_area']= df['living_area'].fillna(df['total_area'] - df['kitchen_area']) # заполняем пропуска в столбце 'living_area' при изместных столбцах 'total_area' , 'kitchen_area' 
df['living_area'] = df['living_area'].fillna(df.groupby('total_area')['living_area'].transform('median'))# остальные пропуски заполняем медианой с группировкой по total_area

# %%
# Код ревьюера

data_copy = df.copy()

# %%
df['ceiling_height'] = df['ceiling_height'].fillna(df.groupby('cityCenters_nearest')['ceiling_height'].transform('median'))# заменили  в столбце 'ceiling_height' пропуски с помощью медианы по группировки 'locality_name'

# %%
# Код ревьюера


data_copy['ceiling_height'] = data_copy['ceiling_height'].astype('float')

data_copy.dropna(subset=['cityCenters_nearest'])\
    .groupby(pd.cut(data_copy['cityCenters_nearest'].dropna().astype('float'), bins=50)).agg(высота_полотков=('ceiling_height','median'))
# Out:
#                       высота_полотков
# cityCenters_nearest
# (115.213, 1496.74]              3.200
# (1496.74, 2812.48]              3.200
# (2812.48, 4128.22]              3.100
# (4128.22, 5443.96]              3.000
# (5443.96, 6759.7]               3.000
# (6759.7, 8075.44]               2.800
# (8075.44, 9391.18]              2.800
# (9391.18, 10706.92]             2.600
# (10706.92, 12022.66]            2.600
# (12022.66, 13338.4]             2.600
# (13338.4, 14654.14]             2.605
# (14654.14, 15969.88]            2.600
# (15969.88, 17285.62]            2.600
# (17285.62, 18601.36]            2.600
# (18601.36, 19917.1]             2.620
# (19917.1, 21232.84]             2.700
# (21232.84, 22548.58]            2.650
# (22548.58, 23864.32]            2.600
# (23864.32, 25180.06]            2.650
# (25180.06, 26495.8]             2.550
# (26495.8, 27811.54]             2.600
# (27811.54, 29127.28]            2.600
# (29127.28, 30443.02]            2.600
# ...

# %%
df.isna().sum() # подсчёт пропусков
# Out:
# total_images               0
# last_price                 0
# total_area                 0
# first_day_exposition       0
# rooms                      0
# ceiling_height          4706
# floors_total               0
# living_area               43
# floor                      0
# is_apartment               0
# studio                     0
# open_plan                  0
# kitchen_area              43
# balcony                    0
# locality_name              0
# airports_nearest        5524
# cityCenters_nearest     5501
# parks_around3000        5500
# parks_nearest           5500
# ponds_around3000        5500
# ponds_nearest           5500
# days_exposition         3171
# dtype: int64

# %% [markdown]
# В столбцах `living_area`,`kitchen_area`,`ceiling_height`  пропуски состаляют менее 1 %. Дальнейшему анализу это не помещает.

# %%
df = df.dropna(subset = ['living_area','kitchen_area','ceiling_height'])# удаляем пропуски в столцах 'living_area','kitchen_area','ceiling_height'

# %%
df['locality_name_lemm'] = df['locality_name'].map(m.lemmatize) # лемматизация столбца 'locality_name'

# %%
df['locality_name_lemm'].value_counts().head(30) #вывод первых 30 строк столбца 'locality_name_lemm'
# Out:
# [санкт-петербург, \n]                    13898
# [поселок,  , шушар, \n]                    349
# [пушкин, \n]                               294
# [поселок,  , парголовый, \n]               292
# [всеволожск, \n]                           272
# [колпино, \n]                              268
# [поселок,  , муриный, \n]                  214
# [петергоф, \n]                             170
# [сестрорецк, \n]                           164
# [гатчина, \n]                              149
# [красный,  , село, \n]                     139
# [деревня,  , кудрово, \n]                  122
# [ломоносов, \n]                            106
# [сертолово, \n]                            101
# [выборг, \n]                                98
# [деревня,  , новый,  , девяткино, \n]       97
# [кириши, \n]                                89
# [кудрово, \n]                               73
# [тосно, \n]                                 70
# [кронштадт, \n]                             70
# ...

# %% [markdown]
# При заполнении колонки `locality_name` указано различное значения  одного и того же адреса. Например: деверня Кудрово и Кудрово.

# %%
for row in ['поселок','село','городской посёлок','посёлок', 'поселок городского типа','коттеджный','садовое товарищество','деревня']:
    
    df['locality_name'] = df['locality_name'].str.replace(row,'')# исключение вида населенного пунка из колонки 'locality_name'

# %%
df['locality_name'] = df['locality_name'].str.replace(" ", "", n = 1)  #Для лучше визуализации прировляем строки к правой стороне (n=1-это аргумент, который заменит только первый найденный символ)

# %%
df['locality_name'] = df['locality_name'].str.lower()# приведение строк в колонке к нижнему регистру

# %%
df['locality_name'].value_counts().head(10) # вывод 10 первых значений столбца 'locality_name'
# Out:
# санкт-петербург    13898
# шушары               349
# пушкин               294
# парголово            292
# всеволожск           272
# колпино              268
# мурино               228
# кудрово              195
# петергоф             170
# сестрорецк           164
# Name: locality_name, dtype: int64

# %% [markdown]
#  Пропуски в колонке 'cityCenters_nearest' связаны с тем ,что до центра населенных пунков очень малое расстояние.

# %%
#df['cityCenters_nearest'] = df['cityCenters_nearest'].fillna('0')# замена колонки 'cityCenters_nearest' на ноль

# %%
df.isna().sum() # подсчёт пропусков
# Out:
# total_images               0
# last_price                 0
# total_area                 0
# first_day_exposition       0
# rooms                      0
# ceiling_height             0
# floors_total               0
# living_area                0
# floor                      0
# is_apartment               0
# studio                     0
# open_plan                  0
# kitchen_area               0
# balcony                    0
# locality_name              0
# airports_nearest        2961
# cityCenters_nearest     2939
# parks_around3000        2938
# parks_nearest           2938
# ponds_around3000        2938
# ponds_nearest           2938
# days_exposition         2701
# locality_name_lemm         0
# dtype: int64

# %% [markdown]
# Заменили пропуски во всех возможных столбцах в исследуемом датафрейме

# %%
df.info() # получение общей информации о данных в таблице df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18829 entries, 0 to 23698
# Data columns (total 23 columns):
# total_images            18829 non-null int64
# last_price              18829 non-null float64
# total_area              18829 non-null float64
# first_day_exposition    18829 non-null object
# rooms                   18829 non-null int64
# ceiling_height          18829 non-null float64
# floors_total            18829 non-null float64
# living_area             18829 non-null float64
# floor                   18829 non-null int64
# is_apartment            18829 non-null bool
# studio                  18829 non-null bool
# open_plan               18829 non-null bool
# kitchen_area            18829 non-null float64
# balcony                 18829 non-null float64
# locality_name           18829 non-null object
# airports_nearest        15868 non-null float64
# cityCenters_nearest     15890 non-null float64
# parks_around3000        15891 non-null float64
# ...

# %% [markdown]
# В дальнейшем для удобства работы в данными изменили типы данных в некоторых столбцах.

# %%
for row in ['last_price','total_area','floors_total','living_area','kitchen_area','balcony']:# замена вещественных значений на целочисленные
    df[row] = df[row].astype('int')

# %%
df['is_apartment'] = df['is_apartment'].astype('bool') # замена  object значений на булевый

# %%
df['last_price'] = df['last_price'] / 1000 # приобразуем в колонке 'last_price' единицу измерения в тыс.

# %%
df.describe() # описание столбцов с числовыми данными.
# Out:
#        total_images     last_price    total_area         rooms  \
# count  18829.000000   18829.000000  18829.000000  18829.000000
# mean      10.120930    6954.305630     61.315471      2.099634
# std        5.686006   11702.160772     36.299241      1.083195
# min        0.000000      12.190000     12.000000      0.000000
# 25%        6.000000    3650.217000     40.000000      1.000000
# 50%       10.000000    4900.000000     53.000000      2.000000
# 75%       14.000000    7100.000000     71.000000      3.000000
# max       50.000000  763000.000000    900.000000     16.000000
#
#        ceiling_height  floors_total   living_area         floor  kitchen_area  \
# count    18829.000000  18829.000000  18829.000000  18829.000000  18829.000000
# mean         2.767388     10.953104     36.067715      6.027936     10.735833
# std          1.173964      6.560393     24.446799      4.907284      6.954891
# min          1.000000      1.000000      2.000000      1.000000      0.000000
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
#  Пропуски обнаружены почти во всех колонках. Не смогли заменить только в колонках `airports_nearest`,`parks_around3000`,`parks_nearest`,`parks_nearest`,`days_exposition`.За неимение дополнительных данных работа с пропусками заканчивается.

# %%
# Код ревьюера

df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'])

# %%
df.loc[df['days_exposition'].notna()]['first_day_exposition'].hist();# гистограмма по столбцу first_day_exposition по срезу без пропусков
plt.show()
df.loc[df['days_exposition'].isna()]['first_day_exposition'].hist();# гистограмма по столбцу first_day_exposition по срезу пропусков
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Произвели замену типов данных. Так в дальнейшем  будет лучше анализировать.

# %% [markdown]
#  Столбец `last_price` изменили единицу измерения.

# %% [markdown]
# Данные подготовлены для установления параметров.

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %%
 df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'],format = '%Y-%m-%dT%H:%M:%S') # изменение формата даты и время

# %%
df['year'] = df['first_day_exposition'].dt.year #создание столбца 'year' и внесение в него года подачи объявления

# %%
df['month'] = df['first_day_exposition'].dt.month#создание столбца 'month' и внесение в него месяца подачи объявления

# %%
df['day'] = df['first_day_exposition'].dt.day # создание столбца 'day' и внесение в него дня подачи объявления

# %%
#df = df.drop(columns = ['first_day_exposition'])# удаление столбца 'first_day_exposition'

# %%
df['price_metr'] = df['last_price']/df['total_area'].astype('int') #добавляем столбец с ценой за квардарный метр

# %%
df['living_to_total'] = df['living_area']/df['total_area'] # добавляем столбец с соотношением жилой площади к общем площади

# %%
df['kitchen_to_total'] = df['kitchen_area']/df['total_area']# добавляем столбец с соотношением площади кухни к общем площади

# %%
def floor_group(row):# функция для замены этажа на первый/последний/другой
    
    floor = row['floor']
    floors_total = row['floors_total']
    
    if floor == 1:
        return 'первый'
    if floor == floors_total:
        return 'последний'
    else:
        
        return 'другой'

# %%
df['floor_group'] = df.apply(floor_group,axis = 1)# с помощью функции apply принимаем функцию floor_group(row)
df[['floor','floors_total','floor_group']].tail(30)# вывод последних 30 строк  столбцов 'floor','floors_total','floor_group'
# Out:
#        floor  floors_total floor_group
# 23661     11            12      другой
# 23662      7            18      другой
# 23663      1            10      первый
# 23664      5             7      другой
# 23667      9            17      другой
# 23668      4             5      другой
# 23670      2             9      другой
# 23671      4             9      другой
# 23672      3             5      другой
# 23673      1             9      первый
# 23674      3             8      другой
# 23675     13            16      другой
# 23676     13            16      другой
# 23677      4             5      другой
# 23678      2             3      другой
# 23680      1             5      первый
# 23681      2             5      другой
# 23682      4             5      другой
# 23683      3             5      другой
# 23684     17            26      другой
# 23685      5             5   последний
# 23686      6             9      другой
# 23687      6             9      другой
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Произвели форматирование столбца с датой и временем. Добавили столбцы с годом,месяцем, днем и с наименованием этажа(первый,последний или другой). Рассчитали цену квадратного метра.

# %% [markdown]
# ## Исследовательский анализ данных

# %%
# %config InlineBackend.figure_format = 'retina'# графики сделали лучше

# %%
# построение диаграммы столбца 'rooms'
#df['rooms'].plot(kind = 'bar');
#plt.show()
df.boxplot(column = ['rooms']);# построние диаграммы размаха столбца 'rooms'

# %% [markdown]
# мода колонки `rooms` находится в значениях от 2 до 3(50% значений). Выбросы по диаграмме размаха находятся начиная от значения в 6.

# %%
df['last_price'].hist(bins = 20, range = (0,40000))# построение диаграммы столбца 'last_price'
plt.show()
ax = df.boxplot(column = ['last_price'],fontsize = 'large',figsize = (8,8))# построние диаграммы размаха столбца 'last_price'
ax.set_ylim(0, 40000);

# %% [markdown]
# Медиана колонки `last_price` находится на отметке чуть ниже 5000. Граница нормального распределения от ноля до 13000. Все,что выше - это выбросы.

# %%
df['total_area'].hist(bins = 20,range = (0,400))# построение диаграммы столбца 'total_area'
plt.show()
df.boxplot(column = ['total_area'],grid = True,figsize = (10,12));# построние диаграммы размаха столбца 'total_area'

# %% [markdown]
# Нормальное распределение в колонке `total_area` находится в рамках от 12 до 150. Мода в отметках с 25 до 75.

# %%
df['ceiling_height'].hist(bins=20,range = (2,5))# построение диаграммы столбца 'ceiling_height'
plt.show()
ax = df.boxplot(column = ['ceiling_height'],figsize = (12,12))# построние диаграммы размаха столбца 'ceiling_height'
ax.set_ylim(0, 4);

# %% [markdown]
# Гистограмма столбца `ceiling_height` показывает нормальное распределение в пиковой точке 2.7 - 2.8. Выбросы начинаются со значений больше 2.8 и меньше 2.6

# %%
df['days_exposition'].hist(bins = 50)# построение диаграммы столбца 'days_exposition'
plt.show()
df.boxplot(column = ['days_exposition'],figsize = (10,12));# построние диаграммы размаха столбца 'days_exposition'

# %% [markdown]
# В колонке `days_exposition` нормальное распределение находится в значениях от 0 до 500.
# В среднем продажа занимает около 95 дней.
# Продажи прошли слишком быстро,когда занимает менее 95 дней.
# Медленно проходящие продажи можно считать от 95 дней.

# %%
df_filter = df.query('days_exposition <= 550 & (2.2 <= ceiling_height <= 3.2) & total_area <= 150 & rooms <= 6 & last_price <= 12000') 
# фильтр,отбрасывающий выбросы в датафрейме

# %%
df_filter.info()# получение общей информации о данных в таблице df_filter
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13382 entries, 4 to 23693
# Data columns (total 30 columns):
# total_images            13382 non-null int64
# last_price              13382 non-null float64
# total_area              13382 non-null int64
# first_day_exposition    13382 non-null datetime64[ns]
# rooms                   13382 non-null int64
# ceiling_height          13382 non-null float64
# floors_total            13382 non-null int64
# living_area             13382 non-null int64
# floor                   13382 non-null int64
# is_apartment            13382 non-null bool
# studio                  13382 non-null bool
# open_plan               13382 non-null bool
# kitchen_area            13382 non-null int64
# balcony                 13382 non-null int64
# locality_name           13382 non-null object
# airports_nearest        11232 non-null float64
# cityCenters_nearest     11243 non-null float64
# parks_around3000        11243 non-null float64
# ...

# %%
pd.set_option('display.max_columns', None) # вывод всех столбцов на экран

# %%
df_filter.corr()# вывод метода корреляции
# Out:
#                      total_images  last_price  total_area     rooms  \
# total_images             1.000000    0.149696    0.088840  0.063508
# last_price               0.149696    1.000000    0.720137  0.457253
# total_area               0.088840    0.720137    1.000000  0.801457
# rooms                    0.063508    0.457253    0.801457  1.000000
# ceiling_height           0.013560    0.413176    0.283469  0.035207
# floors_total             0.006918    0.214826    0.007553 -0.219018
# living_area              0.048216    0.572227    0.886482  0.855395
# floor                    0.026298    0.145331   -0.014237 -0.172514
# is_apartment             0.016206    0.015005    0.007799 -0.013845
# studio                  -0.025580   -0.070083   -0.110041 -0.164216
# open_plan               -0.015983   -0.039776   -0.058698 -0.091098
# kitchen_area             0.043663    0.454471    0.414301  0.063604
# balcony                  0.050501    0.083574    0.081390  0.013603
# ...

# %%
df_corr = df_filter[['total_area','last_price','rooms','ceiling_height','living_area','floor','kitchen_area','floors_total']]

# %%
sns.heatmap(df_corr.corr(),annot = True,vmin = -1, vmax = 1, center = 0);

# %% [markdown]
# Сильная  линейная зависимость к цене прослеживается площадь квартиры в квадратных метрах (м²), количество комнат,жилая площадь,площадь кухни.

# %%
for row in ['total_area','rooms','ceiling_height','living_area','floor','kitchen_area','floors_total']:
    df_filter.plot(x = row ,y = 'last_price', kind = 'scatter',alpha = 0.03, grid = True);# построение диаграммы рассевания

# %% [markdown]
# При увеличении общей площади увеличивается и цена квартиры.Основная концентрация значений приходится на площадь от 30 до 50 м2 и ценой от 3 млн до 5 млн.
#
# Количество комнат находятся в диапозоне от 1 до 3. Цена на них варируется от 2 млн до 8 млн.
#
# Оптимальная высота потолков 2.7. Цена на них от 2 млн до 9 млн.
#
# Скопление значений жилой площади находится в пределах 15 до 20 м2.
#
# Цена за этаж находится от 3 млн до 5 млн.
#
# Частные значения площади кухни от 8  до 12 м2.

# %%
df_filter.pivot_table(index='floor_group',values='price_metr',aggfunc='mean').plot(grid=True,style = 'o-');# график зависимость цены от этажа

# %% [markdown]
# Цена выше,если этаж не последний и не первый. Самым дешевым вариантов остается первый этаж.

# %%
df_filter['year'].hist()# гистограмма колонки 'year'

df_filter.pivot_table(index ='year',values = 'price_metr',aggfunc = 'mean').plot(grid = True,style = 'o-');# график зависимости цены от года публикации объявления

# %% [markdown]
# С 2015 по 2019 цена на квартиру неумолительно растет. Серьезный подъем стоимости квартиры был с 2018 по 2019 год.Медина и среднее значения колонки 'year' равно 2017.

# %%
df_filter['day'].hist(bins=16)# гистограмма колонки 'day'
df_filter.pivot_table(index ='day',values ='price_metr',aggfunc = 'mean').plot(grid = True,style = 'o-');

# %% [markdown]
# При рассмотрении зависимости цены от даты данные слишком разрозенные. Медина и среднее значение равно 15.

# %%
df_filter['month'].hist(bins=12)# гистограмма колонки 'day'
df_filter.pivot_table(index = 'month',values = 'price_metr',aggfunc = 'mean').plot(grid = True,style = 'o-');

# %% [markdown]
# Самым прибыльным месяцев для высталения объявления является март,август,сентябрь. В эти месяц цена на квартиру остается на высоком уровне. Медина и среднее значение равно 7.

# %%
df_price = df_filter.pivot_table(index = 'locality_name',values = 'price_metr',aggfunc = ['count','mean'])#сводная таблица для расчета общего количеста объявлений по населенным пункам и средней цены за квадратный метр 
df_price.columns = ['count_ad','mean_price_metr'] # переименование столбцов
df_price = df_price.sort_values(by = 'count_ad',ascending = False).head(11)#сортируем по убыванию и выводим первые 11 строк
df_price.sort_values(by = 'mean_price_metr',ascending = False)#для наглядности сортируем по цене за квардратный метр
# Out:
#                  count_ad  mean_price_metr
# locality_name
# санкт-петербург      9627       105.326675
# сестрорецк            126       100.731110
# пушкин                206        99.205152
# кудрово               162        95.951419
# парголово             259        90.209298
# мурино                193        88.162557
# петергоф              129        83.498020
# шушары                300        78.606490
# колпино               228        74.806645
# красноесело           112        72.905987
# всеволожск            198        66.464420

# %% [markdown]
# 10 населенных пунктов и Санкт-Петербург с наибольшем числом объявлений. Цена за квадратный метр наибольшая в Санкт-Петербурге. На немного отстает Сестрорецк и Пушкин, которые расположены в непосредстванной близости к Санкт-Петербургу.

# %%
import warnings
warnings.filterwarnings("ignore")

df_filter = df_filter.loc[df_filter['cityCenters_nearest'].notna()]
df_filter['cityCenters_nearest'] = df_filter['cityCenters_nearest'].astype('int')
df_filter['cityCenters_nearest_km'] = df_filter['cityCenters_nearest'] / 1000 #переводим в единицу изменения км
df_filter['cityCenters_nearest_km'] = df_filter['cityCenters_nearest_km'].apply(np.round)#с помощью библиотеки numpy и функции apply округляем до целых значений

# %%
df_filter_spb = df_filter.query('locality_name == "санкт-петербург" & cityCenters_nearest_km != 0')# срез данных

# %%
df_filter_spb.pivot_table(index = 'cityCenters_nearest_km',values = 'last_price',aggfunc = 'mean').plot(grid = True,style = 'o-');
# График, показывающий как цена зависит от удаленности от центра

# %% [markdown]
# По графику видно,что центр приблизительно заканчивается на 7 км. Далее цены выравниваются ,что свидельствует о одинаковых спальных районах. Наблюдаем пик на 20 км вне центра,которые показывают района с улучшенными характеристиками.

# %%
df_spb_center = df_filter_spb.query('cityCenters_nearest_km <= 7')# срез по центру города

# %%
fig, axes = plt.subplots(1,2,figsize=(15,4))
df_spb_center['total_area'].hist(bins=30, ax=axes[0]);
df_filter_spb['total_area'].hist(bins=30, ax=axes[1]);
axes[0].set_title('Распределение площади в центре');
axes[1].set_title('Распределение площади по всему городу');

# %% [markdown]
# Гистограммы распределения показывают практически схожую структуру. Наибольшее значения общей площади лежит в промежутке с 40 до 50 м2.

# %%
fig, axes = plt.subplots(1,2,figsize=(15,4))
df_spb_center['last_price'].hist(bins=30, ax=axes[0]);
df_filter_spb['last_price'].hist(bins=30, ax=axes[1]);
axes[0].set_title('Распределение cтоимости квартиры в центре');
axes[1].set_title('Распределение cтоимости квартиры по всему городу');

# %% [markdown]
# Мода цены по Санкт-Петербургу в целом лежит в значених 3,5 -4,5 млн. А вот мода цены в центре становится свыше 4,5 млн.

# %%
fig, axes = plt.subplots(1,2,figsize=(15,4))
df_spb_center['rooms'].hist(bins=30, ax=axes[0]);
df_filter_spb['rooms'].hist(bins=30, ax=axes[1]);
axes[0].set_title('Распределение количества комнат в центре');
axes[1].set_title('Распределение количества комнат по всему городу');

# %% [markdown]
# По городу в целом однокомнатные квартиры преобладают. Но в центре немного больше двухкомнатных квартир.

# %%
fig, axes = plt.subplots(1,2,figsize=(15,4))
df_spb_center['ceiling_height'].hist(bins=30, ax=axes[0])
df_filter_spb['ceiling_height'].hist(bins=30, ax=axes[1])
axes[0].set_title('Распределение высоты потолков в центре')
axes[1].set_title('Распределение высоты потолков по всему городу')
plt.show()

# %%
# код ревьюера

import matplotlib.pyplot as plt

fig, axes = plt.subplots(1,2,figsize=(15,4))

df_spb_center['ceiling_height'].hist(bins=30, ax=axes[0])
df_filter_spb['ceiling_height'].hist(bins=30, ax=axes[1])

axes[0].set_title('Распределение высоты потолков в центре')
axes[1].set_title('Распределение высоты потолков по всему городу')

plt.show()

# %% [markdown]
# Высота потолков по моде  отличается по центру города. Там мода равно 3 метра. А по Санкт-Петербургу в целом этот показатель составляет 2.7 метра.

# %%
df_filter_spb_pivot = df_filter_spb.pivot_table(index = 'cityCenters_nearest_km',values = 'price_metr',aggfunc = 'mean')
# график зависимости ср. цены за квадратный метр от близости к центру по центру и всему городу
simple = df_spb_center.pivot_table(index = 'cityCenters_nearest_km',values = 'price_metr',aggfunc = 'mean')
ax = df_filter_spb_pivot.plot(y='price_metr',grid = True,style = 'o-',label='SPB')
simple.plot(ax=ax,y='price_metr',grid = True,style = 'o-',label='CENTR');

# %% [markdown]
# Цена за квадратный метр  на квартиры в центре выше ,чем по Санкт-Петербургу в целом.

# %%
df_filter_spb_pivot = df_filter_spb.pivot_table(index='floor_group',values='price_metr',aggfunc='mean')# график зависимости ср. цены за квадратный метр от этажа по центру и всему городу
simple = df_spb_center.pivot_table(index='floor_group',values='price_metr',aggfunc='mean')
ax = df_filter_spb_pivot.plot(y='price_metr',grid = True,style = 'o-',label='SPB')
simple.plot(ax=ax,y='price_metr',grid = True,style = 'o-',label='CENTR');

# %% [markdown]
# Схожая ситуация по этажам. Квартиры расположенные на первом этаже пользуются слабым спросом и цена на них ниже,как по всему городу,так и по центру Санкт-Петербурга.

# %%
df_filter_spb_pivot = df_filter.pivot_table(index = 'month',values = 'price_metr',aggfunc = 'mean')# график зависимости  ср.цены за квадратный метр от месяца по центру и всему городу
simple = df_spb_center.pivot_table(index = 'month',values = 'price_metr',aggfunc = 'mean')
ax = df_filter_spb_pivot.plot(y='price_metr',grid = True,style = 'o-',label='SPB')
simple.plot(ax=ax,y='price_metr',grid = True,style = 'o-',label='CENTR');

# %% [markdown]
# Пик стоимости за квадратный метр по центру Санкт-Петербурга находится в марте и сентябре сопоставим по общему городу.

# %%
df_filter_spb_pivot = df_filter.pivot_table(index = 'year',values = 'price_metr',aggfunc = 'mean')# график зависимости цены за квадратный метр от года по центру и всему городу
simple = df_spb_center.pivot_table(index = 'year',values = 'price_metr',aggfunc = 'mean')
ax = df_filter_spb_pivot.plot(y='price_metr',grid = True,style = 'o-',label='SPB')
simple.plot(ax=ax,y='price_metr',grid = True,style = 'o-',label='CENTR');

# %% [markdown]
# Стоиомсть квардратного метра неукоснительно растет с 2015. Более положительный рост наблюдается по квартирам расположенные в центре.

# %%
df_spb_center.describe() # описание столбцов с числовыми данными.
# Out:
#        total_images    last_price   total_area        rooms  ceiling_height  \
# count   1179.000000   1179.000000  1179.000000  1179.000000     1179.000000
# mean       9.569126   7236.794658    63.132316     2.213740        2.860000
# std        5.513767   2221.249111    22.322177     0.978607        0.208082
# min        0.000000   1600.000000    12.000000     0.000000        2.400000
# 25%        6.000000   5599.500000    45.000000     2.000000        2.700000
# 50%        9.000000   7000.000000    60.000000     2.000000        2.840000
# 75%       13.000000   8750.000000    77.000000     3.000000        3.000000
# max       31.000000  12000.000000   147.000000     6.000000        3.200000
#
#        floors_total  living_area        floor  kitchen_area      balcony  \
# count   1179.000000  1179.000000  1179.000000   1179.000000  1179.000000
# mean       7.626802    37.555556     4.290076     11.188295     0.335878
# ...

# %%
df_filter.describe() # описание столбцов с числовыми данными.
# Out:
#        total_images   last_price    total_area         rooms  ceiling_height  \
# count  11243.000000  11243.00000  11243.000000  11243.000000    11243.000000
# mean       9.824157   5316.34756     52.805123      1.900471        2.668268
# std        5.552817   2026.77567     18.436214      0.892238        0.164866
# min        0.000000     12.19000     12.000000      0.000000        2.300000
# 25%        6.000000   3850.00000     39.000000      1.000000        2.540000
# 50%        9.000000   4800.00000     49.000000      2.000000        2.650000
# 75%       14.000000   6350.00000     63.000000      3.000000        2.750000
# max       50.000000  12000.00000    147.000000      6.000000        3.200000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  11243.000000  11243.000000  11243.000000  11243.000000  11243.000000
# mean      11.961843     30.801299      6.478965      9.611492      0.633639
# ...

# %%
df_filter_spb.corr()#корреляция датафрейма по Санкт-Петербургу
# Out:
#                         total_images  last_price  total_area     rooms  \
# total_images                1.000000    0.142866    0.075881  0.046307
# last_price                  0.142866    1.000000    0.795297  0.507281
# total_area                  0.075881    0.795297    1.000000  0.794728
# rooms                       0.046307    0.507281    0.794728  1.000000
# ceiling_height             -0.001603    0.417918    0.296828  0.046496
# floors_total                0.021364    0.130865    0.005563 -0.244233
# living_area                 0.029294    0.641647    0.887513  0.850969
# floor                       0.035242    0.087539   -0.020150 -0.185225
# is_apartment                0.013108    0.002701   -0.005086 -0.023540
# studio                     -0.017055   -0.082598   -0.109640 -0.168642
# open_plan                  -0.005824   -0.049256   -0.063676 -0.097358
# kitchen_area                0.049335    0.489205    0.420697  0.064138
# ...

# %%
df_spb_center.corr()#корреляция датафрейма по  центру Санкт-Петербургу
# Out:
#                         total_images  last_price  total_area     rooms  \
# total_images                1.000000    0.112614   -0.000661 -0.013596
# last_price                  0.112614    1.000000    0.683204  0.439444
# total_area                 -0.000661    0.683204    1.000000  0.810619
# rooms                      -0.013596    0.439444    0.810619  1.000000
# ceiling_height              0.011328    0.204519    0.278401  0.217778
# floors_total               -0.019702    0.127408   -0.118893 -0.265136
# living_area                -0.034800    0.534847    0.890271  0.831781
# floor                       0.041273    0.159420   -0.037676 -0.144941
# is_apartment               -0.008295   -0.024103   -0.041958 -0.036152
# studio                     -0.035579   -0.105799   -0.108834 -0.188524
# open_plan                  -0.007996   -0.035030   -0.027956 -0.030078
# kitchen_area                0.061372    0.460850    0.364395  0.073604
# ...

# %% [markdown]
# Корреляция столбца `last_price` по центру Санкт-Петербургу  практически аналогична и по всему Санкт-Петербургу. Отличная корреляция наблюдается в столбце `floor`.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Проанализирован датафрейм df, в котором в столбцах 'days_exposition','ceiling_height','total_area','last_price','rooms' обнаружены выбросы.Эти выбросы отбросили для корректной работы.
#
# Цена квартиры по всей исследуемой области зависит от общей площади, площади кухни,жилой площади,высоты потолков, количества комнат.
#
# Часто встречаемые варианты квартир с:
# * 1-3 комнаты;
# * общая площадь 30 - 50 м2;
# * высота потолков 2.7;
# * этаж до 10;
# * жилая площадь 15-20 м2;
# * площадь кухни 8-12 м2.
#
# Цена ниже если квартира находится на первом ,либо последнем этаже.
#
# Начиная с 2017 года цена за квадратный метр  повышается на 12 %.
#
# Март,август и сентябрь в эти месяца стоимость за квадратный метр выше.
#
# Наибольшая средняя цена за квардратный метр среди 10ки населенных пунктов по количеству объявлений составляет 101 тысяча. Это такие города как Сестрорецк и Пушкин. Отличается от средней цена по Санкт-Петербургу на 3 %. Можно предположить,что данные квартиры находятся в престижном населоннном пункте.
#
# Центр Санкт-Петербурга расположен в радиусе 7 км. Стоимость квадратного метра  в центре на 19 % выше,чем по Санкт-Петербургу.Повышение цены происходит схоже по всему городу. Зависимость цены в центре отличается только по этажу. Так потенциальные клиенты доплачивают за квартиру только из-за близости к центру города.
#
# Для вывешивания объявления рационально указывать метраж квартиры, этаж, количество комнат, место расположения и цену. Остальные факты на общую стоимость квартиры влияют косвенно.
